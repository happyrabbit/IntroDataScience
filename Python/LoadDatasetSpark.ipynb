# %%
import pandas as pd
from pyspark.sql.types import StringType, IntegerType, FloatType, StructType, StructField
SegData = pd.read_csv('http://bit.ly/2P5gTw4')
SegData.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>age</th>
#       <th>gender</th>
#       <th>income</th>
#       <th>house</th>
#       <th>store_exp</th>
#       <th>online_exp</th>
#       <th>store_trans</th>
#       <th>online_trans</th>
#       <th>Q1</th>
#       <th>Q2</th>
#       <th>Q3</th>
#       <th>Q4</th>
#       <th>Q5</th>
#       <th>Q6</th>
#       <th>Q7</th>
#       <th>Q8</th>
#       <th>Q9</th>
#       <th>Q10</th>
#       <th>segment</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>57</td>
#       <td>Female</td>
#       <td>120963.400958</td>
#       <td>Yes</td>
#       <td>529.134363</td>
# ...

# %%
disease_dat = pd.read_csv('http://bit.ly/2KXb1Qi')
disease_dat.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Q1.A</th>
#       <th>Q1.B</th>
#       <th>Q2.A</th>
#       <th>Q2.B</th>
#       <th>Q3.A</th>
#       <th>Q3.B</th>
#       <th>Q4.A</th>
#       <th>Q4.B</th>
#       <th>Q5.A</th>
#       <th>Q5.B</th>
#       <th>Q6.A</th>
#       <th>Q6.B</th>
#       <th>Q7.A</th>
#       <th>Q7.B</th>
#       <th>Q8.A</th>
#       <th>Q8.B</th>
#       <th>Q9.A</th>
#       <th>Q9.B</th>
#       <th>Q10.A</th>
#       <th>Q10.B</th>
#       <th>Q11.A</th>
#       <th>Q11.B</th>
#       <th>Q12.A</th>
#       <th>Q12.B</th>
#       <th>Q13.A</th>
#       <th>Q13.B</th>
#       <th>Q14.A</th>
#       <th>Q14.B</th>
# ...

# %%
rating = pd.read_csv('http://bit.ly/2TNQ6TK')
rating.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Easy_Reservation</th>
#       <th>Preferred_Seats</th>
#       <th>Flight_Options</th>
#       <th>Ticket_Prices</th>
#       <th>Seat_Comfort</th>
#       <th>Seat_Roominess</th>
#       <th>Overhead_Storage</th>
#       <th>Clean_Aircraft</th>
#       <th>Courtesy</th>
#       <th>Friendliness</th>
#       <th>Helpfulness</th>
#       <th>Service</th>
#       <th>Satisfaction</th>
#       <th>Fly_Again</th>
#       <th>Recommend</th>
#       <th>ID</th>
#       <th>Airline</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>6</td>
#       <td>5</td>
#       <td>4</td>
# ...

# %%
# SegData.dtypes
# schemaFields_SegData = StructType([StructField("age", IntegerType(), False),
#                 StructField("gender", StringType(), False),
#                 StructField("income", FloatType(), False),
#                 StructField("house", StringType(), False),
#                 StructField("store_exp", FloatType(), False),
#                 StructField("online_exp", FloatType(), False),
#                 StructField("store_trans", IntegerType(), False),
#                 StructField("online_trans", IntegerType(), False),
#                 StructField("Q1", IntegerType(), False),
#                 StructField("Q2", IntegerType(), False),
#                 StructField("Q3", IntegerType(), False),
#                 StructField("Q4", IntegerType(), False),
#                 StructField("Q5", IntegerType(), False),
#                 StructField("Q6", IntegerType(), False),
#                 StructField("Q7", IntegerType(), False),
#                 StructField("Q8", IntegerType(), False),
#                 StructField("Q9", IntegerType(), False),           
#                 StructField("Q10", IntegerType(), False),
#                 StructField("segment", StringType(), False)])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# create spark dataframe
SegData_df = spark.createDataFrame(SegData)
# write data
SegData_df.write.format("parquet").mode("overwrite").save("/databricks/IDS/SegData_df")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# create spark dataframe
rating_df = spark.createDataFrame(rating)
# write data
rating_df.write.format("parquet").mode("overwrite").save("/databricks/IDS/rating_df")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# create spark dataframe
disease_dat_df = spark.createDataFrame(disease_dat)
# write data
disease_dat_df.write.format("parquet").mode("overwrite").save("/databricks/IDS/disease_dat_df")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %sql
/* Create database */
CREATE DATABASE IF NOT EXISTS IDS
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
/* create table in the database and point to the location */
drop table if exists IDS.SegData_df;
CREATE TABLE IDS.SegData_df
USING parquet
LOCATION '/databricks/IDS/SegData_df';
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
/* create table in the database and point to the location */
drop table if exists IDS.rating_df;
CREATE TABLE IDS.rating_df
USING parquet
LOCATION '/databricks/IDS/rating_df';
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
/* create table in the database and point to the location */
drop table if exists IDS.disease_dat_df;
CREATE TABLE IDS.disease_dat_df
USING parquet
LOCATION '/databricks/IDS/disease_dat_df';
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>
