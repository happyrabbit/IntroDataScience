# %% [markdown]
# # Introducing Spark DataFrames
#
# A Spark DataFrame is conceptually equivalent to other DataFrames we are more familiar with, Pandas or R DataFrames. The key difference is that Spark DataFrame has richer optimizations under the hood and the benefit of being distributed across a cluster.
#
# Under the covers, Spark DataFrames are immutable distributed collections of data, aka Resilient Distributed Datasets (RDDs).
#
# * **Resilient**: They are fault-tolerant, so if part of your operation fails, Spark quickly recovers the lost computation.
# * **Distributed**: RDDs are distributed across networked machines known as a cluster.
# * **DataFrame**: A data structure where data is organized into named columns, like a table in a relational database, but with richer optimizations under the hood.
#
# Let's first create a new schema called `IDS` in Databricks and added some tables to the schema. Load and run this [notebook]([https://github.com/happyrabbit/IntroDataScience/blob/master/Python/LoadDatasetSpark.ipynb](https://github.com/happyrabbit/IntroDataScience/blob/master/Python/LoadDatasetSpark.ipynb)).

# %% [markdown]
# # Read and write data
#
# You can run SQL queries to read data from the schema we just created with the special syntax `spark.sql("SELECT * FROM myTable")`

# %%
from pyspark.sql import functions as F
SimDat = spark.sql("select * from ids.segdata_df")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
## Check the head of the data
## show the top 6 rows
SimDat.show(6)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---+------+------------------+-----+------------------+-----------------+-----------+------------+---+---+---+---+---+---+---+---+---+---+-----------+
# age|gender|            income|house|         store_exp|       online_exp|store_trans|online_trans| Q1| Q2| Q3| Q4| Q5| Q6| Q7| Q8| Q9|Q10|    segment|
# +---+------+------------------+-----+------------------+-----------------+-----------+------------+---+---+---+---+---+---+---+---+---+---+-----------+
#  42|  Male|  293009.811755997|  Yes|  5114.77993658565| 4798.79414739255|         12|           9|  1|  4|  5|  4|  4|  4|  4|  1|  4|  1|Conspicuous|
#  33|  Male|  174461.035852419|  Yes|  3916.76067388849|7322.934531126509|          7|          14|  1|  4|  5|  4|  4|  4|  4|  1|  4|  2|Conspicuous|
#  43|Female|  190407.357307437|  Yes|  4694.92232135798|7875.562442717529|          6|          11|  1|  4|  5|  4|  4|  4|  4|  1|  4|  2|Conspicuous|
#  50|Female|  110149.313517391|  Yes|5102.7668466591995| 5478.85702604015|         11|          14|  1|  4|  4|  4|  4|  4|  4|  1|  4|  1|Conspicuous|
#  38|Female|  247626.234595709|  Yes|  5731.83879848872| 5340.25441107555|         12|           7|  1|  4|  5|  4|  4|  4|  4|  1|  4|  1|Conspicuous|
#  42|  Male|205640.67311489602|  Yes|   5294.5684933747| 4751.08824383356|         10|          14|  1|  4|  5|  4|  4|  4|  4|  1|  4|  1|Conspicuous|
# +---+------+------------------+-----+------------------+-----------------+-----------+------------+---+---+---+---+---+---+---+---+---+---+-----------+
# only showing top 6 rows
#
# </div>

# %% [markdown]
# # Tidy and Reshape Data
#
# We will illustrate the data manipulations in order:
#
# - Display
# - Query
# - Summarize
# - Create new variable
# - Merge
# - Reshape data

# %% [markdown]
# ## Display
#
# `describe` function can generate descriptive statistics of each column. The descriptive statistics include
#
# * Count – Count of values of each column
# * Mean – Mean value of each column
# * Stddev – standard deviation of each column
# * Min – Minimum value of each column
# * Max – Maximum value of each column

# %%
display(SimDat.describe())
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>summary</th><th>age</th><th>gender</th><th>income</th><th>house</th><th>store_exp</th><th>online_exp</th><th>store_trans</th><th>online_trans</th><th>Q1</th><th>Q2</th><th>Q3</th><th>Q4</th><th>Q5</th><th>Q6</th><th>Q7</th><th>Q8</th><th>Q9</th><th>Q10</th><th>segment</th></tr></thead><tbody><tr><td>count</td><td>1000</td><td>1000</td><td>816</td><td>1000</td><td>1000</td><td>1000</td><td>1000</td><td>1000</td><td>1000</td><td>1000</td><td>1000</td><td>1000</td><td>1000</td><td>1000</td><td>1000</td><td>1000</td><td>1000</td><td>1000</td><td>1000</td></tr><tr><td>mean</td><td>38.84</td><td>null</td><td>113543.06522194942</td><td>null</td><td>1356.850523048724</td><td>2120.1811872603525</td><td>5.35</td><td>13.546</td><td>3.101</td><td>1.823</td><td>1.992</td><td>2.763</td><td>2.945</td><td>2.448</td><td>3.434</td><td>2.396</td><td>3.085</td><td>2.32</td><td>null</td></tr><tr><td>stddev</td><td>16.416817959394926</td><td>null</td><td>49842.28719659571</td><td>null</td><td>2774.39978497596</td><td>1731.2243079138482</td><td>3.695559112929619</td><td>7.956959042071111</td><td>1.4501385802404894</td><td>1.1683475664527387</td><td>1.4021062377373203</td><td>1.155060675966923</td><td>1.2843771348885904</td><td>1.4385288893051</td><td>1.455940851739439</td><td>1.1543467921367978</td><td>1.118492747417714</td><td>1.1361737943162085</td><td>null</td></tr><tr><td>min</td><td>16</td><td>Female</td><td>41775.637022548</td><td>No</td><td>-500.0</td><td>68.81722750413141</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>1</td><td>Conspicuous</td></tr><tr><td>max</td><td>300</td><td>Male</td><td>319704.337940878</td><td>Yes</td><td>50000.0</td><td>9479.44230953055</td><td>20</td><td>36</td><td>5</td><td>5</td><td>5</td><td>5</td><td>5</td><td>5</td><td>5</td><td>5</td><td>5</td><td>5</td><td>Style</td></tr></tbody></table></div>

# %%
# Columns
SimDat.columns
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[9]: [&#39;age&#39;,
#  &#39;gender&#39;,
#  &#39;income&#39;,
#  &#39;house&#39;,
#  &#39;store_exp&#39;,
#  &#39;online_exp&#39;,
#  &#39;store_trans&#39;,
#  &#39;online_trans&#39;,
#  &#39;Q1&#39;,
#  &#39;Q2&#39;,
#  &#39;Q3&#39;,
#  &#39;Q4&#39;,
#  &#39;Q5&#39;,
#  &#39;Q6&#39;,
#  &#39;Q7&#39;,
#  &#39;Q8&#39;,
#  &#39;Q9&#39;,
#  &#39;Q10&#39;,
#  &#39;segment&#39;]</div>

# %%
# Column Data Type
SimDat.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- age: long (nullable = true)
# -- gender: string (nullable = true)
# -- income: double (nullable = true)
# -- house: string (nullable = true)
# -- store_exp: double (nullable = true)
# -- online_exp: double (nullable = true)
# -- store_trans: long (nullable = true)
# -- online_trans: long (nullable = true)
# -- Q1: long (nullable = true)
# -- Q2: long (nullable = true)
# -- Q3: long (nullable = true)
# -- Q4: long (nullable = true)
# -- Q5: long (nullable = true)
# -- Q6: long (nullable = true)
# -- Q7: long (nullable = true)
# -- Q8: long (nullable = true)
# -- Q9: long (nullable = true)
# -- Q10: long (nullable = true)
# -- segment: string (nullable = true)
#
# </div>

# %% [markdown]
# ## Query
#
# DataFrame syntax is more flexible than SQL syntax. Here we illustrate general usage patterns of SQL and DataFrames.
#
# Suppose we have a data set we loaded as a table called `myTable` and an equivalent DataFrame, called `df`.
# We have three fields/columns called `col_1` (numeric type), `col_2` (string type) and `col_3` (timestamp type)
# Here are basic SQL operations and their DataFrame equivalents.
#
# Notice that columns in DataFrames are referenced by `col("<columnName>")`.
#
# | SQL                                         | DataFrame (Python)                    |
# | ------------------------------------------- | ------------------------------------- |
# | `SELECT col_1 FROM myTable`                 | `df.select(col("col_1"))`             |
# | `DESCRIBE myTable`                          | `df.printSchema()`                    |
# | `SELECT * FROM myTable WHERE col_1 > 0`     | `df.filter(col("col_1") > 0)`         |
# | `.GROUP BY col_2`                          | `.groupBy(col("col_2"))`             |
# | `.ORDER BY col_2`                          | `.orderBy(col("col_2"))`             |
# | `.WHERE year(col_3) > 1990`                | `.filter(year(col("col_3")) > 1990)` |
# | `SELECT * FROM myTable LIMIT 10`            | `df.limit(10)`                        |
# | `display(myTable)` (text format)            | `df.show()`                           |
# | `display(myTable)` (html format)            | `display(df)`                         |

# %%
# Select rows that meet logical criteria. For example, get rows with income more than 300000

SubDat = SimDat.filter(F.col('income') > 300000)
display(SubDat)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>age</th><th>gender</th><th>income</th><th>house</th><th>store_exp</th><th>online_exp</th><th>store_trans</th><th>online_trans</th><th>Q1</th><th>Q2</th><th>Q3</th><th>Q4</th><th>Q5</th><th>Q6</th><th>Q7</th><th>Q8</th><th>Q9</th><th>Q10</th><th>segment</th></tr></thead><tbody><tr><td>41</td><td>Male</td><td>317476.198766336</td><td>Yes</td><td>3029.8442719051</td><td>4179.6706964163795</td><td>11</td><td>12</td><td>1</td><td>4</td><td>5</td><td>4</td><td>4</td><td>4</td><td>4</td><td>1</td><td>4</td><td>2</td><td>Conspicuous</td></tr><tr><td>37</td><td>Female</td><td>315697.156955637</td><td>Yes</td><td>6548.97012066964</td><td>4284.06452951059</td><td>13</td><td>11</td><td>1</td><td>4</td><td>5</td><td>4</td><td>4</td><td>4</td><td>4</td><td>1</td><td>4</td><td>2</td><td>Conspicuous</td></tr><tr><td>40</td><td>Male</td><td>301398.026985122</td><td>Yes</td><td>4840.46078736722</td><td>3618.2119986302205</td><td>10</td><td>11</td><td>1</td><td>4</td><td>4</td><td>4</td><td>4</td><td>4</td><td>4</td><td>1</td><td>4</td><td>1</td><td>Conspicuous</td></tr><tr><td>33</td><td>Male</td><td>319704.337940878</td><td>Yes</td><td>5998.305280860251</td><td>4395.9231681151505</td><td>9</td><td>11</td><td>1</td><td>4</td><td>4</td><td>4</td><td>4</td><td>4</td><td>4</td><td>1</td><td>4</td><td>2</td><td>Conspicuous</td></tr></tbody></table></div>

# %%
# get records with age between 20 and 40
SubDat = SimDat.filter(SimDat.age.between(20,40))
display(SubDat)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>age</th><th>gender</th><th>income</th><th>house</th><th>store_exp</th><th>online_exp</th><th>store_trans</th><th>online_trans</th><th>Q1</th><th>Q2</th><th>Q3</th><th>Q4</th><th>Q5</th><th>Q6</th><th>Q7</th><th>Q8</th><th>Q9</th><th>Q10</th><th>segment</th></tr></thead><tbody><tr><td>33</td><td>Male</td><td>174461.035852419</td><td>Yes</td><td>3916.76067388849</td><td>7322.934531126509</td><td>7</td><td>14</td><td>1</td><td>4</td><td>5</td><td>4</td><td>4</td><td>4</td><td>4</td><td>1</td><td>4</td><td>2</td><td>Conspicuous</td></tr><tr><td>38</td><td>Female</td><td>247626.234595709</td><td>Yes</td><td>5731.83879848872</td><td>5340.25441107555</td><td>12</td><td>7</td><td>1</td><td>4</td><td>5</td><td>4</td><td>4</td><td>4</td><td>4</td><td>1</td><td>4</td><td>1</td><td>Conspicuous</td></tr><tr><td>37</td><td>Male</td><td>197545.892379841</td><td>Yes</td><td>5287.41480092342</td><td>4221.309359340789</td><td>8</td><td>11</td><td>1</td><td>4</td><td>5</td><td>4</td><td>4</td><td>4</td><td>4</td><td>1</td><td>4</td><td>1</td><td>Conspicuous</td></tr><tr><td>34</td><td>Female</td><td>210712.440204045</td><td>Yes</td><td>5257.71802698796</td><td>4838.52722735659</td><td>13</td><td>10</td><td>1</td><td>4</td><td>4</td><td>4</td><td>4</td><td>4</td><td>4</td><td>1</td><td>4</td><td>1</td><td>Conspicuous</td></tr><tr><td>30</td><td>Male</td><td>null</td><td>Yes</td><td>5130.69569642776</td><td>4546.07858685111</td><td>9</td><td>7</td><td>1</td><td>4</td><td>4</td><td>4</td><td>4</td><td>4</td><td>4</td><td>1</td><td>4</td><td>2</td><td>Conspicuous</td></tr><tr><td>38</td><td>Male</td><td>110136.83262448301</td><td>Yes</td><td>4364.83797108174</td><td>4809.2466659957</td><td>17</td><td>10</td><td>1</td><td>4</td><td>5</td><td>4</td><td>4</td><td>4</td><td>4</td><td>1</td><td>4</td><td>2</td><td>Conspicuous</td></tr><tr><td>38</td><td>Male</td><td>220745.714756061</td><td>Yes</td><td>5318.03454397684</td><td>4468.867575897701</td><td>14</td><td>18</td><td>1</td><td>4</td><td>4</td><td>4</td><td>4</td><td>4</td><td>4</td><td>1</td><td>4</td><td>2</td><td>Conspicuous</td></tr><tr><td>38</td><td>Female</td><td>271749.669436335</td><td>Yes</td><td>5275.00282248712</td><td>3813.2107303581</td><td>5</td><td>15</td><td>1</td><td>4</td><td>4</td><td>4</td><td>4</td><td>4</td><td>4</td><td>1</td><td>4</td><td>2</td><td>Conspicuous</td></tr><tr><td>37</td><td>Male</td><td>139062.795876456</td><td>Yes</td><td>4070.6805018801897</td><td>7595.57843440283</td><td>16</td><td>13</td><td>1</td><td>4</td><td>4</td><td>4</td><td>4</td><td>4</td><td>4</td><td>1</td><td>4</td><td>1</td><td>Conspicuous</td></tr><tr><td>33</td><td>Male</td><td>102389.638269935</td><td>Yes</td><td>4070.7665201076397</td><td>5683.644832397979</td><td>13</td><td>11</td><td>1</td><td>4</td><td>4</td><td>4</td><td>4</td><td>4</td><td>4</td><td>1</td><td>4</td><td>1</td><td>Conspicuous</td></tr><tr><td>36</td><td>Male</td><td>228550.06074346</td><td>Yes</td><td>3279.6208091934996</td><td>8220.55543606859</td><td>8</td><td>12</td><td>1</td><td>4</td><td>5</td><td>4</td><td>4</td><td>4</td><td>4</td><td>1</td><td>4</td><td>1</td><td>Conspicuous</td></tr><tr><td>38</td><td>Female</td><td>181306.875922374</td><td>Yes</td><td>3142.75728522243</td><td>3806.8074028366295</td><td>8</td><td>13</td><td>1</td><td>4</td><td>4</td><td>4</td><td>4</td><td>4</td><td>4</td><td>1</td><td>4</td><td>1</td><td>Conspicuous</td></tr><tr><td>34</td><td>Male</td><td>252650.784909281</td><td>Yes</td><td>5310.27993311305</td><td>4312.206245511071</td><td>10</td><td>12</td><td>1</td><td>4</td><td>5</td><td>4</td><td>4</td><td>4</td><td>4</td><td>1</td><td>4</td><td>1</td><td>Conspicuous</td></tr><tr><td>39</td><td>Male</td><td>259350.474522765</td><td>Yes</td><td>50000.0</td><td>3172.2616744405896</td><td>13</td><td>11</td><td>1</td><td>4</td><td>4</td><td>4</td><td>4</td><td>4</td><td>4</t ...

# %%
# select columns
SubDat = SimDat.select('age','gender','income')
SubDat.show(3)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---+------+
# age|gender|
# +---+------+
#  42|  Male|
#  33|  Male|
#  43|Female|
# +---+------+
# only showing top 3 rows
#
# </div>

# %%
# sort and look at the top n records
SimDat.sort(col("income").desc()).show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---+------+----------------+-----+------------------+------------------+-----------+------------+---+---+---+---+---+---+---+---+---+---+-----------+
# age|gender|          income|house|         store_exp|        online_exp|store_trans|online_trans| Q1| Q2| Q3| Q4| Q5| Q6| Q7| Q8| Q9|Q10|    segment|
# +---+------+----------------+-----+------------------+------------------+-----------+------------+---+---+---+---+---+---+---+---+---+---+-----------+
#  33|  Male|319704.337940878|  Yes| 5998.305280860251|4395.9231681151505|          9|          11|  1|  4|  4|  4|  4|  4|  4|  1|  4|  2|Conspicuous|
#  41|  Male|317476.198766336|  Yes|   3029.8442719051|4179.6706964163795|         11|          12|  1|  4|  5|  4|  4|  4|  4|  1|  4|  2|Conspicuous|
#  37|Female|315697.156955637|  Yes|  6548.97012066964|  4284.06452951059|         13|          11|  1|  4|  5|  4|  4|  4|  4|  1|  4|  2|Conspicuous|
#  40|  Male|301398.026985122|  Yes|  4840.46078736722|3618.2119986302205|         10|          11|  1|  4|  4|  4|  4|  4|  4|  1|  4|  1|Conspicuous|
#  44|  Male|295423.107590685|   No|5460.0960732904605|  5598.65776898424|         11|          12|  1|  4|  4|  4|  4|  4|  4|  1|  4|  2|Conspicuous|
# +---+------+----------------+-----+------------------+------------------+-----------+------------+---+---+---+---+---+---+---+---+---+---+-----------+
# only showing top 5 rows
#
# </div>

# %%
# Delete duplicated rows.
SimDat.dropDuplicates()

# %% [markdown]
# ## Summarize
#
# A standard marketing problem is customer segmentation. It usually starts with designing survey and collecting data. Then run a cluster analysis on the data to get customer segments. Once we have different segments, the next is to understand how each group of customer look like by summarizing some key metrics. For example, we can do the following data aggregation for different segments of clothes customers.

# %%
df = (SimDat
      # here we import pyspark.sql.functions as F
      .withColumn('isFemale',  F.when(SimDat["gender"] == "Female", 1).otherwise(0))
      .groupby('segment')
      .agg({'age': 'mean',
            'store_trans': 'mean',
            'online_trans': 'mean',
           'isFemale': 'mean'})
      )
df.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----------+----------------+------------------+------------------+-----------------+
#     segment|avg(store_trans)|     avg(isFemale)|          avg(age)|avg(online_trans)|
# +-----------+----------------+------------------+------------------+-----------------+
#       Style|            3.04|0.8085714285714286|24.382857142857144|21.13142857142857|
# Conspicuous|           10.88|             0.325|            41.625|           11.075|
#     Quality|           2.865|              0.47|            35.425|            15.97|
#       Price|           6.148|             0.448|            59.584|            2.964|
# +-----------+----------------+------------------+------------------+-----------------+
#
# </div>

# %%
# change column names
df = (df
      .withColumnRenamed('avg(store_trans)','avg_store_trans')
      .withColumnRenamed('avg(age)','avg_age')
      .withColumnRenamed('avg(online_trans)','avg_online_trans')
      .withColumnRenamed('avg(isFemale))','female_pct')
     )
df.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----------+---------------+------------------+------------------+-----------------+
#     segment|avg_store_trans|     avg(isFemale)|           avg_age| avg_online_trans|
# +-----------+---------------+------------------+------------------+-----------------+
#       Style|           3.04|0.8085714285714286|24.382857142857144|21.13142857142857|
# Conspicuous|          10.88|             0.325|            41.625|           11.075|
#     Quality|          2.865|              0.47|            35.425|            15.97|
#       Price|          6.148|             0.448|            59.584|            2.964|
# +-----------+---------------+------------------+------------------+-----------------+
#
# </div>

# %% [markdown]
# ## Create new variable
#
# You can use `.withColumn` function to create new column based on the current columns. We used this function when we summarized the data (`.withColumn('isFemale',  F.when(SimDat["gender"] == "Female", 1).otherwise(0))`). If you want to get a new column that tells if `store_trans` is larger than `online_trans`, you can do:

# %%
SimDat.withColumn('store_lg_online', SimDat.store_trans > SimDat.online_trans).show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---+------+----------------+-----+------------------+-----------------+-----------+------------+---+---+---+---+---+---+---+---+---+---+-----------+---------------+
# age|gender|          income|house|         store_exp|       online_exp|store_trans|online_trans| Q1| Q2| Q3| Q4| Q5| Q6| Q7| Q8| Q9|Q10|    segment|store_lg_online|
# +---+------+----------------+-----+------------------+-----------------+-----------+------------+---+---+---+---+---+---+---+---+---+---+-----------+---------------+
#  42|  Male|293009.811755997|  Yes|  5114.77993658565| 4798.79414739255|         12|           9|  1|  4|  5|  4|  4|  4|  4|  1|  4|  1|Conspicuous|           true|
#  33|  Male|174461.035852419|  Yes|  3916.76067388849|7322.934531126509|          7|          14|  1|  4|  5|  4|  4|  4|  4|  1|  4|  2|Conspicuous|          false|
#  43|Female|190407.357307437|  Yes|  4694.92232135798|7875.562442717529|          6|          11|  1|  4|  5|  4|  4|  4|  4|  1|  4|  2|Conspicuous|          false|
#  50|Female|110149.313517391|  Yes|5102.7668466591995| 5478.85702604015|         11|          14|  1|  4|  4|  4|  4|  4|  4|  1|  4|  1|Conspicuous|          false|
#  38|Female|247626.234595709|  Yes|  5731.83879848872| 5340.25441107555|         12|           7|  1|  4|  5|  4|  4|  4|  4|  1|  4|  1|Conspicuous|           true|
# +---+------+----------------+-----+------------------+-----------------+-----------+------------+---+---+---+---+---+---+---+---+---+---+-----------+---------------+
# only showing top 5 rows
#
# </div>

# %% [markdown]
# ## Merge
# We create two baby data sets to show how merge works.

# %%
dfx = spark.createDataFrame([
  ('A', 1.0, 'online'),
  ('B', 2.0, 'store'),
  ('C', 3.0, 'online')
], 
  ["ID", "x1", "type"]
)

display(dfx)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>ID</th><th>x1</th><th>type</th></tr></thead><tbody><tr><td>A</td><td>1.0</td><td>online</td></tr><tr><td>B</td><td>2.0</td><td>store</td></tr><tr><td>C</td><td>3.0</td><td>online</td></tr></tbody></table></div>

# %%
dfy = spark.createDataFrame([
  ('B', True),
  ('C', True),
  ('D', False),
  ('E', True)
], 
  ["ID", "y1"]
)

display(dfy)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>ID</th><th>y1</th></tr></thead><tbody><tr><td>B</td><td>true</td></tr><tr><td>C</td><td>true</td></tr><tr><td>D</td><td>false</td></tr><tr><td>E</td><td>true</td></tr></tbody></table></div>

# %%
# Join matching rows from dfy to dfx
dfx.join(dfy, how = 'left', on = 'ID').show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---+---+------+----+
#  ID| x1|  type|  y1|
# +---+---+------+----+
#   B|  2| store|true|
#   C|  3|online|true|
#   A|  1|online|null|
# +---+---+------+----+
#
# </div>

# %%
# Retain only rows in both sets
dfx.join(dfy, how = 'inner', on = 'ID').show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---+---+------+----+
#  ID| x1|  type|  y1|
# +---+---+------+----+
#   B|  2| store|true|
#   C|  3|online|true|
# +---+---+------+----+
#
# </div>

# %%
# Retain all values, all rows
df_outer = dfx.join(dfy, how = 'outer', on = 'ID')
df_outer.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---+----+------+-----+
#  ID|  x1|  type|   y1|
# +---+----+------+-----+
#   E|null|  null| true|
#   B| 2.0| store| true|
#   D|null|  null|false|
#   C| 3.0|online| true|
#   A| 1.0|online| null|
# +---+----+------+-----+
#
# </div>

# %% [markdown]
# ## Imputing Null or Missing Data
#
# Null values refer to unknown or missing data as well as irrelevant responses. Strategies for dealing with this scenerio include:<br><br>
#
# * **Dropping these records:** Works when you do not need to use the information for downstream workloads
# * **Adding a placeholder (e.g. `-1`):** Allows you to see missing data later on without violating a schema
# * **Basic imputing:** Allows you to have a "best guess" of what the data could have been, often by using the mean of non-missing data
# * **Advanced imputing:** Determines the "best guess" of what data should be using more advanced strategies such as clustering machine learning algorithms or oversampling techniques
#
# Let's use the `df_outer` data frame as an example.

# %%
# Drop any records that have null values.
DroppedNa = df_outer.dropna("any")
DroppedNa.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---+---+------+----+
#  ID| x1|  type|  y1|
# +---+---+------+----+
#   B|  2| store|true|
#   C|  3|online|true|
# +---+---+------+----+
#
# </div>

# %%
# Impute values with the mean.
from pyspark.ml.feature import Imputer
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# only support numerical column
imputer = Imputer(strategy='mean', inputCols=["x1"], outputCols=["out_x1"])
model = imputer.fit(df_outer)
model.transform(df_outer).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---+----+------+-----+------+
#  ID|  x1|  type|   y1|out_x1|
# +---+----+------+-----+------+
#   E|null|  null| true|   2.0|
#   B| 2.0| store| true|   2.0|
#   D|null|  null|false|   2.0|
#   C| 3.0|online| true|   3.0|
#   A| 1.0|online| null|   1.0|
# +---+----+------+-----+------+
#
# </div>

# %%
ImputedDF = df_outer.na.fill({"type": "store", "y1": True})
ImputedDF.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---+----+------+-----+
#  ID|  x1|  type|   y1|
# +---+----+------+-----+
#   E|null| store| true|
#   B| 2.0| store| true|
#   D|null| store|false|
#   C| 3.0|online| true|
#   A| 1.0|online| true|
# +---+----+------+-----+
#
# </div>

# %% [markdown]
# ## Reshape data
#
# Take a baby subset of our exemplary clothes consumers data to illustrate.

# %%
sdat = (SimDat
          .sample(False, 0.1)
          .select('age', 'gender', 'income','house', 'store_exp', 'online_exp')
         .dropna('any')
         )
  
sdat.show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---+------+------------------+-----+------------------+------------------+
# age|gender|            income|house|         store_exp|        online_exp|
# +---+------+------------------+-----+------------------+------------------+
#  33|  Male|  174461.035852419|  Yes|  3916.76067388849| 7322.934531126509|
#  42|  Male|177698.86912623898|  Yes|  5135.39579908169|   7255.3561799391|
#  38|Female|  181306.875922374|  Yes|  3142.75728522243|3806.8074028366295|
#  25|Female|  69245.4699238543|  Yes|  380.837297125242|  2189.33438844906|
#  38|Female|  60944.9217615233|  Yes|296.65243614587996|  2160.56882008242|
# +---+------+------------------+-----+------------------+------------------+
# only showing top 5 rows
#
# </div>

# %% [markdown]
# For the above data `sdat`, what if we want to have a variable indicating the purchasing channel (i.e. online or in-store) and another column with the corresponding expense amount? Assume we want to keep the rest of the columns the same. It is a task to change data from “wide” to “long”. There are two general ways to shape data:
#
# - Use `melt()` to convert an object into a molten data frame, i.e., from wide to long (function defined below)
# - Use `pivot()` to cast a molten data frame into the shape you want, i.e., from long to wide

# %%
from pyspark.sql.functions import array, col, explode, lit, struct

def melt(df, id_vars, value_vars, var_name, value_name):
    """Convert :class:`DataFrame` from wide to long format."""
    _vars_and_vals = F.array(*[F.struct(F.lit(c).alias(var_name),
                                        F.col(c).alias(value_name)) 
                               for c in value_vars])

    # Add to the DataFrame and explode
    _tmp = df.withColumn("_vars_and_vals", F.explode(_vars_and_vals))

    cols = id_vars + [F.col("_vars_and_vals")[x].alias(x) for x in [var_name, value_name]]
    return _tmp.select(*cols)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
melt_sdat = melt(sdat,  ['age','gender'], ['store_exp','online_exp'], 'Channel','Expense')
melt_sdat.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---+------+----------+------------------+
# age|gender|   Channel|           Expense|
# +---+------+----------+------------------+
#  33|  Male| store_exp|  3916.76067388849|
#  33|  Male|online_exp| 7322.934531126509|
#  42|  Male| store_exp|  5135.39579908169|
#  42|  Male|online_exp|   7255.3561799391|
#  38|Female| store_exp|  3142.75728522243|
#  38|Female|online_exp|3806.8074028366295|
#  25|Female| store_exp|  380.837297125242|
#  25|Female|online_exp|  2189.33438844906|
#  38|Female| store_exp|296.65243614587996|
#  38|Female|online_exp|  2160.56882008242|
#  33|Female| store_exp|  189.117882590504|
#  33|Female|online_exp|2005.6905607503197|
#  30|  Male| store_exp|  298.728349274718|
#  30|  Male|online_exp|2208.7656392113604|
#  33|  Male| store_exp|   345.27727104371|
#  33|  Male|online_exp|1843.2254373319502|
#  28|  Male| store_exp|  330.368137539975|
#  28|  Male|online_exp|  1783.44175967716|
#  49|Female| store_exp|330.93103953523604|
#  49|Female|online_exp|  2191.16061390117|
# +---+------+----------+------------------+
# only showing top 20 rows
#
# </div>

# %% [markdown]
# You melted the data frame `sdat` by two variables: `store_exp` and `online_exp`. The new variable name is `Channel` . The value name is `Expense`.
#
# Sometimes we want to convert the data from “long” to “wide”. For example, you want to compare the online and in-store expense between male and female.

# %%
pivot_sdat = melt_sdat.groupby("gender").pivot("Channel").agg({'Expense': 'mean'})
pivot_sdat.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+------+------------------+------------------+
# gender|        online_exp|         store_exp|
# +------+------------------+------------------+
# Female|1990.1114233827955| 533.2865054835038|
#   Male| 2474.314938776524|1403.5667244675683|
# +------+------------------+------------------+
#
# </div>
